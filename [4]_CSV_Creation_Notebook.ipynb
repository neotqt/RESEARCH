# %% [markdown]
# # <font color='#fff200'> **Notebook Purpose and Introduction**
#
# ### **Purpose**
# To create the Randomized Music Dataset, the Training Dataset, and the Testing Dataset which is then organized into a single CSV File.
#
# ### **Introduction**
# Combining all datasets into a single CSV file helps in organizing the data in a structured manner. This makes it easier to manage and maintain the datasets, reducing the risk of data duplication or inconsistency.
#
# Splitting the dataset into training and testing sets is crucial for evaluating the performance of machine learning models. The training set is used to train the model, while the testing set is used to assess its performance on unseen data. This helps in estimating how well the model generalizes to new, unseen music samples.

# %% [markdown]
# # **Necessary Libraries and Installations**

# %%
# !pip install mido

# %%
# !pip install midi2audio

# %%
# !pip install pydub

# %%
# !sudo apt-get install fluidsynth

# %%
# !pip install python_speech_features

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import sys
import music21
import soundfile as sf
import csv
import scipy.io.wavfile as wav
import pickle
import random
import operator
import math
import shutil
import subprocess
import time

from librosa import midi_to_hz
from midi2audio import FluidSynth
from mido import MidiFile, MidiTrack, tempo2bpm
from pydub import AudioSegment
from music21 import converter, stream, meter
from fractions import Fraction
from scipy.signal import find_peaks
from python_speech_features import mfcc
from tempfile import TemporaryFile
from collections import defaultdict

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# # **Random Music Set Creation**

# %%
iterations = 150

for i in range(iterations):
  print("Iteration:", i)
  print()
  # !python /content/drive/Shareddrives/neotyagi-dataset/random-notes/generatemono.py 15
  print()
  print('=' * 100)
  print()
  time.sleep(1)
# Out:
# Iteration: 0
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav000.wav complete.
#
# Input #0, wav, from '/tmp/tmpuz28ia6q.wav':
#   Duration: 00:00:28.31, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpuz28ia6q.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 1
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav001.wav complete.
#
# Input #0, wav, from '/tmp/tmpigfpeq23.wav':
#   Duration: 00:00:28.43, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpigfpeq23.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 2
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav002.wav complete.
#
# Input #0, wav, from '/tmp/tmprroj3f4g.wav':
#   Duration: 00:00:25.20, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmprroj3f4g.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 3
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav003.wav complete.
#
# Input #0, wav, from '/tmp/tmpu4njvd2y.wav':
#   Duration: 00:00:23.10, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpu4njvd2y.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 4
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav004.wav complete.
#
# Input #0, wav, from '/tmp/tmpz087hnma.wav':
#   Duration: 00:00:26.18, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpz087hnma.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 5
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav005.wav complete.
#
# Input #0, wav, from '/tmp/tmpa2qrq8hd.wav':
#   Duration: 00:00:29.81, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpa2qrq8hd.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 6
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav006.wav complete.
#
# Input #0, wav, from '/tmp/tmpq81tg6vj.wav':
#   Duration: 00:00:26.73, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpq81tg6vj.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 7
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav007.wav complete.
#
# Input #0, wav, from '/tmp/tmpjgcn9o1o.wav':
#   Duration: 00:00:24.52, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpjgcn9o1o.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 8
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav008.wav complete.
#
# Input #0, wav, from '/tmp/tmpzdh94k37.wav':
#   Duration: 00:00:26.04, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpzdh94k37.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 9
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav009.wav complete.
#
# Input #0, wav, from '/tmp/tmpe3mn1o9g.wav':
#   Duration: 00:00:27.53, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpe3mn1o9g.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 10
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav010.wav complete.
#
# Input #0, wav, from '/tmp/tmpnverib5j.wav':
#   Duration: 00:00:25.47, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpnverib5j.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 11
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav011.wav complete.
#
# Input #0, wav, from '/tmp/tmptrrtjgtw.wav':
#   Duration: 00:00:28.31, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmptrrtjgtw.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 12
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav012.wav complete.
#
# Input #0, wav, from '/tmp/tmpl222xnb4.wav':
#   Duration: 00:00:29.80, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpl222xnb4.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 13
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav013.wav complete.
#
# Input #0, wav, from '/tmp/tmp7ak1cd0e.wav':
#   Duration: 00:00:25.38, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp7ak1cd0e.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 14
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav014.wav complete.
#
# Input #0, wav, from '/tmp/tmpae06q8kz.wav':
#   Duration: 00:00:23.60, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpae06q8kz.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 15
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav015.wav complete.
#
# Input #0, wav, from '/tmp/tmp8_mhrtbp.wav':
#   Duration: 00:00:26.17, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp8_mhrtbp.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 16
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav016.wav complete.
#
# Input #0, wav, from '/tmp/tmpf5ekrnxx.wav':
#   Duration: 00:00:22.64, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpf5ekrnxx.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 17
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav017.wav complete.
#
# Input #0, wav, from '/tmp/tmpvljceesk.wav':
#   Duration: 00:00:28.33, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpvljceesk.wav' or configure filtergraph
#
#
# ====================================================================================================
#
# Iteration: 18
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav018.wav complete.
#
# Input #0, wav, from '/tmp/tmpanys5e3c.wav':
#   Duration: 00:00:20.33, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpanys5e3c.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 19
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav019.wav complete.
#
# Input #0, wav, from '/tmp/tmpsphla6df.wav':
#   Duration: 00:00:24.55, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpsphla6df.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 20
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav020.wav complete.
#
# Input #0, wav, from '/tmp/tmpid9dbmjo.wav':
#   Duration: 00:00:25.27, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpid9dbmjo.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 21
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav021.wav complete.
#
# Input #0, wav, from '/tmp/tmpuhsvef9i.wav':
#   Duration: 00:00:27.14, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpuhsvef9i.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 22
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav022.wav complete.
#
# Input #0, wav, from '/tmp/tmp23q0d79o.wav':
#   Duration: 00:00:25.19, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ...
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpfvpl0d0h.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 143
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmpiqy30vog.wav':
#   Duration: 00:00:28.19, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpiqy30vog.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 144
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav144.wav complete.
#
# Input #0, wav, from '/tmp/tmpg8skt9po.wav':
#   Duration: 00:00:27.45, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpg8skt9po.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 145
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav145.wav complete.
#
# Input #0, wav, from '/tmp/tmp3kgmpiye.wav':
#   Duration: 00:00:23.41, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp3kgmpiye.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 146
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav146.wav complete.
#
# Input #0, wav, from '/tmp/tmpnc2c7238.wav':
#   Duration: 00:00:25.23, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpnc2c7238.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 147
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav147.wav complete.
#
# Input #0, wav, from '/tmp/tmpjwbbgvv1.wav':
#   Duration: 00:00:27.39, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpjwbbgvv1.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 148
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav148.wav complete.
#
# Input #0, wav, from '/tmp/tmpbtqxo84j.wav':
#   Duration: 00:00:28.06, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpbtqxo84j.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 149
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetMono/randomMONOwav149.wav complete.
#
# Input #0, wav, from '/tmp/tmp2idg5e0p.wav':
#   Duration: 00:00:24.18, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp2idg5e0p.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================

# %%
iterations = 10

for i in range(iterations):
  print("Iteration:", i)
  print()
  # !python /content/drive/Shareddrives/neotyagi-dataset/random-notes/generatepoly.py 5
  print()
  print('=' * 100)
  print()
  time.sleep(3)
# Out:
# Iteration: 0
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmpbqj5bgyz.wav':
#   Duration: 00:00:24.46, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpbqj5bgyz.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 1
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmp19juhsr5.wav':
#   Duration: 00:00:34.67, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp19juhsr5.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 2
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmpax7nkrko.wav':
#   Duration: 00:00:29.27, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpax7nkrko.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 3
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmptg560td3.wav':
#   Duration: 00:00:27.55, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmptg560td3.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 4
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmpn6gcux29.wav':
#   Duration: 00:00:25.13, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpn6gcux29.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 5
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmpbhenp2jq.wav':
#   Duration: 00:00:27.15, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpbhenp2jq.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 6
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmp28ml8kkc.wav':
#   Duration: 00:00:33.06, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp28ml8kkc.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 7
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmpwmby9sj7.wav':
#   Duration: 00:00:28.40, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmpwmby9sj7.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================
#
# Iteration: 8
#
# /content/drive/Shareddrives/neotyagi-dataset/random-notes/generatepoly.py:103: RuntimeWarning: invalid value encountered in divide
#   signal /= numpy.max(numpy.abs(signal)) / PCM_SCALE
# Traceback (most recent call last):
#   File "/content/drive/Shareddrives/neotyagi-dataset/random-notes/generatepoly.py", line 112, in <module>
#     ssignal += struct.pack('h', int(signal[j]))
# ValueError: cannot convert float NaN to integer
#
# ====================================================================================================
#
# Iteration: 9
#
#
# Generation for /content/drive/Shareddrives/neotyagi-dataset/GarbageSetPoly/randomPOLYwav143.wav complete.
#
# Input #0, wav, from '/tmp/tmp52u4bzzq.wav':
#   Duration: 00:00:28.66, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (2 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# SDL_OpenAudio (1 channels, 44100 Hz): ALSA: Couldn't open audio device: No such file or directory
# No more combinations to try, audio open failed
# Failed to open file '/tmp/tmp52u4bzzq.wav' or configure filtergraph
#     nan    :  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#
# ====================================================================================================

# %% [markdown]
# # **Training/Testing Set Creation**

# %%
def truncateMidiToDurationForMaestro(inputFile, outputFile, duration = 30):
  oldMidi = MidiFile(inputFile)
  newMidi = MidiFile(ticks_per_beat = oldMidi.ticks_per_beat)
  newTrack = MidiTrack()

  ticksPerSec = oldMidi.ticks_per_beat * tempo2bpm(oldMidi.tracks[0][0].tempo) / 60 # Calculate the ticks per second based on the tempo of the MIDI file
  desiredTicks = int(ticksPerSec * duration)                                    # Calculate the desired ticks to achieve the specified duration

  currentTicks = 0
  for track in oldMidi.tracks:
      newTrack = MidiTrack()
      currentTicks = 0
      for msg in track:
          currentTicks += msg.time
          if currentTicks > desiredTicks:

              timeRemaining = desiredTicks - (currentTicks - msg.time)          # Calculate the time remaining to reach the desired duration
              msg.time = timeRemaining                                          # Adjust the time of the current message to fit the desired duration
              newTrack.append(msg)
              break
          newTrack.append(msg)
      newMidi.tracks.append(newTrack)
  newMidi.save(outputFile)

def truncateMidiToDurationForNottingham(inputFile, outputFile, duration = 30):
    oldMidi = MidiFile(inputFile)
    newMidi = MidiFile(ticks_per_beat=oldMidi.ticks_per_beat)
    newTrack = MidiTrack()

    default_tempo = 500000                                                      # Default tempo in microseconds per beat (500000 microseconds = 120 BPM) - in case tempo information is not available.
    ticksPerSec = oldMidi.ticks_per_beat * tempo2bpm(default_tempo) / 60

    desiredTicks = int(ticksPerSec * duration)
    currentTicks = 0

    for track in oldMidi.tracks:
        newTrack = MidiTrack()
        for msg in track:
            currentTicks += msg.time
            if currentTicks > desiredTicks:
                break
            newTrack.append(msg)
        newMidi.tracks.append(newTrack)

    newMidi.save(outputFile)

################################################################################

# Truncating Source Directory
sourceDirectory = "/content/drive/Shareddrives/neotyagi-dataset/nottingham-dataset-master/MIDI/melody"
duration = 30
for filename in os.listdir(sourceDirectory):
    if "maestro" in sourceDirectory:
      if filename.endswith(".midi") and not filename.endswith("TRUNCATED.midi"):
        inputFilePath = os.path.join(sourceDirectory, filename)
        outputFilePath = os.path.join(sourceDirectory, filename[:-5] + "TRUNCATED.midi")
        truncateMidiToDurationForMaestro(inputFilePath, outputFilePath, duration)
    else:
      if filename.endswith(".mid") and not filename.endswith("TRUNCATED.mid"):
        inputFilePath = os.path.join(sourceDirectory, filename)
        outputFilePath = os.path.join(sourceDirectory, filename[:-4] + "TRUNCATED.mid")
        truncateMidiToDurationForNottingham(inputFilePath, outputFilePath, duration)
print(f"Files truncated successfully.")

# %%
# Translating MIDI to WAV

sourceDirectory = "/content/drive/Shareddrives/neotyagi-dataset/nottingham-dataset-master/MIDI/melody"
for filename in os.listdir(sourceDirectory):
  if ("maestro" in sourceDirectory):
    if filename.endswith("TRUNCATED.midi"):
      filepath = os.path.join(sourceDirectory, filename)
      filepathWAV = filepath[:-5] + '.wav'
      fs = FluidSynth()
      fs.midi_to_audio(filepath, filepathWAV)
      print(f"Translated {filename} to WAV successfully.")
  else:
    if filename.endswith("TRUNCATED.mid"):
      filepath = os.path.join(sourceDirectory, filename)
      filepathWAV = filepath[:-4]+'.wav'
      fs = FluidSynth()
      fs.midi_to_audio(filepath, filepathWAV)
      print(f"Translated {filename} to WAV successfully.")

# %%
# Organizing TRUNCATED.wav Files

sourceDirectory = "/content/drive/Shareddrives/neotyagi-dataset/nottingham-dataset-master/MIDI/melody"
destinationDirectory = "/content/drive/Shareddrives/neotyagi-dataset/nottingham-dataset-master/MIDI/NottinghamSets"
flagToMove = "TRUNCATED.wav"
filesMovedCount = 0

os.makedirs(destinationDirectory, exist_ok = True)                              # Create the destination directory if it does not exist

for filename in os.listdir(sourceDirectory):
    if filename.endswith(flagToMove):
        sourcePath = os.path.join(sourceDirectory, filename)
        destinationPath = os.path.join(destinationDirectory, filename)
        shutil.move(sourcePath, destinationPath)
        filesMovedCount += 1
print(f"{filesMovedCount} files have been moved.")
# Out:
# 983 files have been moved.

# %% [markdown]
# # **Data to CSV**

# %%
fileDataList = []
fileNumber = 1
csvTest = "/content/drive/Shareddrives/neotyagi-dataset/maestro-v3.0.0/MaestroTest/[7] CSV Test"
# csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
# csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
# csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
# csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
# csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
# csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvTest):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvTest, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'csvTest.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [Copy of Copy of Copy of MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1TRUNCATED.wav]
#
# File 2: Finished appending data for [Copy of Copy of randomPOLYwav015.wav]
#
# File 3: Finished appending data for [Copy of Copy of randomMONOwav141.wav]
#
# Data has been written to csvTest.csv

# %%
fileDataList = []
fileNumber = 1
csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
# csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
# csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
# csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
# csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
# csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvMonophonicTrain):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvMonophonicTrain, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'monoNottinghamTrain.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [xmas12TRUNCATED.wav]
#
# File 2: Finished appending data for [xmas6TRUNCATED.wav]
#
# File 3: Finished appending data for [xmas5TRUNCATED.wav]
#
# File 4: Finished appending data for [waltzes16TRUNCATED.wav]
#
# File 5: Finished appending data for [waltzes2TRUNCATED.wav]
#
# File 6: Finished appending data for [reelsu-z11TRUNCATED.wav]
#
# File 7: Finished appending data for [waltzes46TRUNCATED.wav]
#
# File 8: Finished appending data for [waltzes11TRUNCATED.wav]
#
# File 9: Finished appending data for [waltzes49TRUNCATED.wav]
#
# File 10: Finished appending data for [waltzes42TRUNCATED.wav]
#
# File 11: Finished appending data for [xmas4TRUNCATED.wav]
#
# File 12: Finished appending data for [reelsu-z9TRUNCATED.wav]
#
# File 13: Finished appending data for [slip8TRUNCATED.wav]
#
# File 14: Finished appending data for [reelsu-z34TRUNCATED.wav]
#
# File 15: Finished appending data for [reelsu-z32TRUNCATED.wav]
#
# File 16: Finished appending data for [slip7TRUNCATED.wav]
#
# File 17: Finished appending data for [waltzes50TRUNCATED.wav]
#
# File 18: Finished appending data for [waltzes40TRUNCATED.wav]
#
# File 19: Finished appending data for [reelsu-z18TRUNCATED.wav]
#
# File 20: Finished appending data for [waltzes26TRUNCATED.wav]
#
# File 21: Finished appending data for [reelsu-z6TRUNCATED.wav]
#
# File 22: Finished appending data for [slip1TRUNCATED.wav]
#
# File 23: Finished appending data for [reelsu-z7TRUNCATED.wav]
#
# File 24: Finished appending data for [slip6TRUNCATED.wav]
#
# File 25: Finished appending data for [waltzes25TRUNCATED.wav]
#
# File 26: Finished appending data for [waltzes5TRUNCATED.wav]
#
# File 27: Finished appending data for [waltzes9TRUNCATED.wav]
#
# File 28: Finished appending data for [reelsu-z8TRUNCATED.wav]
#
# File 29: Finished appending data for [xmas9TRUNCATED.wav]
#
# File 30: Finished appending data for [reelsu-z22TRUNCATED.wav]
#
# File 31: Finished appending data for [waltzes19TRUNCATED.wav]
#
# File 32: Finished appending data for [waltzes13TRUNCATED.wav]
#
# File 33: Finished appending data for [waltzes31TRUNCATED.wav]
#
# File 34: Finished appending data for [reelsu-z16TRUNCATED.wav]
#
# File 35: Finished appending data for [slip11TRUNCATED.wav]
#
# File 36: Finished appending data for [waltzes39TRUNCATED.wav]
#
# File 37: Finished appending data for [waltzes15TRUNCATED.wav]
#
# File 38: Finished appending data for [slip5TRUNCATED.wav]
#
# File 39: Finished appending data for [xmas11TRUNCATED.wav]
#
# File 40: Finished appending data for [waltzes43TRUNCATED.wav]
#
# File 41: Finished appending data for [waltzes23TRUNCATED.wav]
#
# File 42: Finished appending data for [waltzes30TRUNCATED.wav]
#
# File 43: Finished appending data for [reelsu-z15TRUNCATED.wav]
#
# File 44: Finished appending data for [xmas1TRUNCATED.wav]
#
# File 45: Finished appending data for [slip4TRUNCATED.wav]
#
# File 46: Finished appending data for [waltzes14TRUNCATED.wav]
#
# File 47: Finished appending data for [waltzes37TRUNCATED.wav]
#
# File 48: Finished appending data for [reelsu-z31TRUNCATED.wav]
#
# File 49: Finished appending data for [xmas2TRUNCATED.wav]
#
# File 50: Finished appending data for [xmas10TRUNCATED.wav]
#
# File 51: Finished appending data for [reelsu-z10TRUNCATED.wav]
#
# File 52: Finished appending data for [waltzes1TRUNCATED.wav]
#
# File 53: Finished appending data for [waltzes38TRUNCATED.wav]
#
# File 54: Finished appending data for [waltzes8TRUNCATED.wav]
#
# File 55: Finished appending data for [reelsu-z13TRUNCATED.wav]
#
# File 56: Finished appending data for [waltzes24TRUNCATED.wav]
#
# File 57: Finished appending data for [slip2TRUNCATED.wav]
#
# File 58: Finished appending data for [reelsu-z33TRUNCATED.wav]
#
# File 59: Finished appending data for [waltzes10TRUNCATED.wav]
#
# File 60: Finished appending data for [waltzes34TRUNCATED.wav]
#
# File 61: Finished appending data for [reelsu-z25TRUNCATED.wav]
#
# File 62: Finished appending data for [reelsu-z19TRUNCATED.wav]
#
# File 63: Finished appending data for [waltzes4TRUNCATED.wav]
#
# File 64: Finished appending data for [waltzes41TRUNCATED.wav]
#
# File 65: Finished appending data for [waltzes17TRUNCATED.wav]
#
# File 66: Finished appending data for [waltzes52TRUNCATED.wav]
#
# File 67: Finished appending data for [waltzes45TRUNCATED.wav]
#
# File 68: Finished appending data for [waltzes36TRUNCATED.wav]
#
# File 69: Finished appending data for [slip9TRUNCATED.wav]
#
# File 70: Finished appending data for [waltzes27TRUNCATED.wav]
#
# File 71: Finished appending data for [xmas7TRUNCATED.wav]
#
# File 72: Finished appending data for [waltzes6TRUNCATED.wav]
#
# File 73: Finished appending data for [reelsu-z23TRUNCATED.wav]
#
# File 74: Finished appending data for [xmas8TRUNCATED.wav]
#
# File 75: Finished appending data for [waltzes32TRUNCATED.wav]
#
# File 76: Finished appending data for [reelsu-z26TRUNCATED.wav]
#
# File 77: Finished appending data for [waltzes51TRUNCATED.wav]
#
# File 78: Finished appending data for [waltzes44TRUNCATED.wav]
#
# File 79: Finished appending data for [waltzes47TRUNCATED.wav]
#
# File 80: Finished appending data for [slip10TRUNCATED.wav]
#
# File 81: Finished appending data for [reelsu-z27TRUNCATED.wav]
#
# File 82: Finished appending data for [waltzes3TRUNCATED.wav]
#
# File 83: Finished appending data for [xmas3TRUNCATED.wav]
#
# File 84: Finished appending data for [reelsu-z12TRUNCATED.wav]
#
# File 85: Finished appending data for [reelsu-z17TRUNCATED.wav]
#
# File 86: Finished appending data for [waltzes35TRUNCATED.wav]
#
# File 87: Finished appending data for [reelsu-z29TRUNCATED.wav]
#
# File 88: Finished appending data for [waltzes20TRUNCATED.wav]
#
# File 89: Finished appending data for [waltzes7TRUNCATED.wav]
#
# File 90: Finished appending data for [waltzes33TRUNCATED.wav]
#
# File 91: Finished appending data for [waltzes48TRUNCATED.wav]
#
# File 92: Finished appending data for [waltzes29TRUNCATED.wav]
#
# File 93: Finished appending data for [reelsu-z21TRUNCATED.wav]
#
# File 94: Finished appending data for [xmas13TRUNCATED.wav]
#
# File 95: Finished appending data for [waltzes21TRUNCATED.wav]
#
# File 96: Finished appending data for [waltzes12TRUNCATED.wav]
#
# File 97: Finished appending data for [reelsu-z30TRUNCATED.wav]
#
# File 98: Finished appending data for [reelsu-z20TRUNCATED.wav]
#
# File 99: Finished appending data for [slip3TRUNCATED.wav]
#
# File 100: Finished appending data for [reelsu-z24TRUNCATED.wav]
#
# File 101: Finished appending data for [Copy of randomMONOwav028.wav]
#
# File 102: Finished appending data for [Copy of randomMONOwav026.wav]
#
# File 103: Finished appending data for [Copy of randomMONOwav025.wav]
#
# File 104: Finished appending data for [Copy of randomMONOwav029.wav]
#
# File 105: Finished appending data for [Copy of randomMONOwav030.wav]
#
# File 106: Finished appending data for [Copy of randomMONOwav033.wav]
#
# File 107: Finished appending data for [Copy of randomMONOwav032.wav]
#
# File 108: Finished appending data for [Copy of randomMONOwav031.wav]
#
# File 109: Finished appending data for [Copy of randomMONOwav034.wav]
#
# File 110: Finished appending data for [Copy of randomMONOwav027.wav]
#
# File 111: Finished appending data for [Copy of randomMONOwav044.wav]
#
# File 112: Finished appending data for [Copy of randomMONOwav038.wav]
#
# File 113: Finished appending data for [Copy of randomMONOwav040.wav]
#
# File 114: Finished appending data for [Copy of randomMONOwav036.wav]
#
# File 115: Finished appending data for [Copy of randomMONOwav042.wav]
#
# File 116: Finished appending data for [Copy of randomMONOwav041.wav]
#
# File 117: Finished appending data for [Copy of randomMONOwav039.wav]
#
# File 118: Finished appending data for [Copy of randomMONOwav035.wav]
#
# File 119: Finished appending data for [Copy of randomMONOwav043.wav]
#
# File 120: Finished appending data for [Copy of randomMONOwav037.wav]
#
# File 121: Finished appending data for [Copy of randomMONOwav045.wav]
#
# File 122: Finished appending data for [Copy of randomMONOwav054.wav]
#
# File 123: Finished appending data for [Copy of randomMONOwav047.wav]
#
# File 124: Finished appending data for [Copy of randomMONOwav048.wav]
#
# File 125: Finished appending data for [Copy of randomMONOwav051.wav]
#
# File 126: Finished appending data for [Copy of randomMONOwav052.wav]
#
# File 127: Finished appending data for [Copy of randomMONOwav053.wav]
#
# File 128: Finished appending data for [Copy of randomMONOwav050.wav]
#
# File 129: Finished appending data for [Copy of randomMONOwav049.wav]
#
# File 130: Finished appending data for [Copy of randomMONOwav046.wav]
#
# File 131: Finished appending data for [Copy of randomMONOwav055.wav]
#
# File 132: Finished appending data for [Copy of randomMONOwav059.wav]
#
# File 133: Finished appending data for [Copy of randomMONOwav064.wav]
#
# File 134: Finished appending data for [Copy of randomMONOwav058.wav]
#
# File 135: Finished appending data for [Copy of randomMONOwav063.wav]
#
# File 136: Finished appending data for [Copy of randomMONOwav056.wav]
#
# File 137: Finished appending data for [Copy of randomMONOwav061.wav]
#
# File 138: Finished appending data for [Copy of randomMONOwav060.wav]
#
# File 139: Finished appending data for [Copy of randomMONOwav057.wav]
#
# File 140: Finished appending data for [Copy of randomMONOwav062.wav]
#
# File 141: Finished appending data for [Copy of randomMONOwav069.wav]
#
# File 142: Finished appending data for [Copy of randomMONOwav073.wav]
#
# File 143: Finished appending data for [Copy of randomMONOwav066.wav]
#
# File 144: Finished appending data for [Copy of randomMONOwav065.wav]
#
# File 145: Finished appending data for [Copy of randomMONOwav068.wav]
#
# File 146: Finished appending data for [Copy of randomMONOwav071.wav]
#
# File 147: Finished appending data for [Copy of randomMONOwav072.wav]
#
# File 148: Finished appending data for [Copy of randomMONOwav067.wav]
#
# File 149: Finished appending data for [Copy of randomMONOwav070.wav]
#
# File 150: Finished appending data for [Copy of randomMONOwav074.wav]
#
# Data has been written to monoNottinghamTrain.csv

# %%
fileDataList = []
fileNumber = 1
# csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
# csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
# csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
# csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
# csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvPolyphonicTrain):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvPolyphonicTrain, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'polyMaestroTrain.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1TRUNCATED.wav]
#
# File 2: Finished appending data for [MIDI-Unprocessed_Chamber4_MID--AUDIO_11_R3_2018_wav--1TRUNCATED.wav]
#
# File 3: Finished appending data for [MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1TRUNCATED.wav]
#
# File 4: Finished appending data for [MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--2TRUNCATED.wav]
#
# File 5: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--4TRUNCATED.wav]
#
# File 6: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--3TRUNCATED.wav]
#
# File 7: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--2TRUNCATED.wav]
#
# File 8: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--4TRUNCATED.wav]
#
# File 9: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--1TRUNCATED.wav]
#
# File 10: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--3TRUNCATED.wav]
#
# File 11: Finished appending data for [MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1TRUNCATED.wav]
#
# File 12: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--5TRUNCATED.wav]
#
# File 13: Finished appending data for [MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1TRUNCATED.wav]
#
# File 14: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--1TRUNCATED.wav]
#
# File 15: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--2TRUNCATED.wav]
#
# File 16: Finished appending data for [MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--2TRUNCATED.wav]
#
# File 17: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--2TRUNCATED.wav]
#
# File 18: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--1TRUNCATED.wav]
#
# File 19: Finished appending data for [MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4TRUNCATED.wav]
#
# File 20: Finished appending data for [MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--1TRUNCATED.wav]
#
# File 21: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--3TRUNCATED.wav]
#
# File 22: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--4TRUNCATED.wav]
#
# File 23: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--2TRUNCATED.wav]
#
# File 24: Finished appending data for [MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--5TRUNCATED.wav]
#
# File 25: Finished appending data for [MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--2TRUNCATED.wav]
#
# File 26: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--3TRUNCATED.wav]
#
# File 27: Finished appending data for [MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--2TRUNCATED.wav]
#
# File 28: Finished appending data for [MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3TRUNCATED.wav]
#
# File 29: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--3TRUNCATED.wav]
#
# File 30: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--1TRUNCATED.wav]
#
# File 31: Finished appending data for [MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--4TRUNCATED.wav]
#
# File 32: Finished appending data for [MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--6TRUNCATED.wav]
#
# File 33: Finished appending data for [MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--4TRUNCATED.wav]
#
# File 34: Finished appending data for [MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4TRUNCATED.wav]
#
# File 35: Finished appending data for [MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1TRUNCATED.wav]
#
# File 36: Finished appending data for [MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--3TRUNCATED.wav]
#
# File 37: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--1TRUNCATED.wav]
#
# File 38: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--2TRUNCATED.wav]
#
# File 39: Finished appending data for [MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--5TRUNCATED.wav]
#
# File 40: Finished appending data for [MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--1TRUNCATED.wav]
#
# File 41: Finished appending data for [MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--3TRUNCATED.wav]
#
# File 42: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2TRUNCATED.wav]
#
# File 43: Finished appending data for [MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--1TRUNCATED.wav]
#
# File 44: Finished appending data for [MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--2TRUNCATED.wav]
#
# File 45: Finished appending data for [MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--2TRUNCATED.wav]
#
# File 46: Finished appending data for [MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--1TRUNCATED.wav]
#
# File 47: Finished appending data for [MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--4TRUNCATED.wav]
#
# File 48: Finished appending data for [MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--3TRUNCATED.wav]
#
# File 49: Finished appending data for [MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--1TRUNCATED.wav]
#
# File 50: Finished appending data for [MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--3TRUNCATED.wav]
#
# File 51: Finished appending data for [Copy of randomPOLYwav027.wav]
#
# File 52: Finished appending data for [Copy of randomPOLYwav034.wav]
#
# File 53: Finished appending data for [Copy of randomPOLYwav029.wav]
#
# File 54: Finished appending data for [Copy of randomPOLYwav028.wav]
#
# File 55: Finished appending data for [Copy of randomPOLYwav032.wav]
#
# File 56: Finished appending data for [Copy of randomPOLYwav030.wav]
#
# File 57: Finished appending data for [Copy of randomPOLYwav035.wav]
#
# File 58: Finished appending data for [Copy of randomPOLYwav033.wav]
#
# File 59: Finished appending data for [Copy of randomPOLYwav025.wav]
#
# File 60: Finished appending data for [Copy of randomPOLYwav031.wav]
#
# File 61: Finished appending data for [Copy of randomPOLYwav039.wav]
#
# File 62: Finished appending data for [Copy of randomPOLYwav041.wav]
#
# File 63: Finished appending data for [Copy of randomPOLYwav040.wav]
#
# File 64: Finished appending data for [Copy of randomPOLYwav037.wav]
#
# File 65: Finished appending data for [Copy of randomPOLYwav042.wav]
#
# File 66: Finished appending data for [Copy of randomPOLYwav038.wav]
#
# File 67: Finished appending data for [Copy of randomPOLYwav045.wav]
#
# File 68: Finished appending data for [Copy of randomPOLYwav043.wav]
#
# File 69: Finished appending data for [Copy of randomPOLYwav036.wav]
#
# File 70: Finished appending data for [Copy of randomPOLYwav046.wav]
#
# File 71: Finished appending data for [Copy of randomPOLYwav053.wav]
#
# File 72: Finished appending data for [Copy of randomPOLYwav050.wav]
#
# File 73: Finished appending data for [Copy of randomPOLYwav047.wav]
#
# File 74: Finished appending data for [Copy of randomPOLYwav054.wav]
#
# File 75: Finished appending data for [Copy of randomPOLYwav048.wav]
#
# File 76: Finished appending data for [Copy of randomPOLYwav057.wav]
#
# File 77: Finished appending data for [Copy of randomPOLYwav058.wav]
#
# File 78: Finished appending data for [Copy of randomPOLYwav052.wav]
#
# File 79: Finished appending data for [Copy of randomPOLYwav051.wav]
#
# File 80: Finished appending data for [Copy of randomPOLYwav055.wav]
#
# File 81: Finished appending data for [Copy of randomPOLYwav064.wav]
#
# File 82: Finished appending data for [Copy of randomPOLYwav060.wav]
#
# File 83: Finished appending data for [Copy of randomPOLYwav062.wav]
#
# File 84: Finished appending data for [Copy of randomPOLYwav063.wav]
#
# File 85: Finished appending data for [Copy of randomPOLYwav065.wav]
#
# File 86: Finished appending data for [Copy of randomPOLYwav066.wav]
#
# File 87: Finished appending data for [Copy of randomPOLYwav061.wav]
#
# File 88: Finished appending data for [Copy of randomPOLYwav067.wav]
#
# File 89: Finished appending data for [Copy of randomPOLYwav059.wav]
#
# File 90: Finished appending data for [Copy of randomPOLYwav068.wav]
#
# File 91: Finished appending data for [Copy of randomPOLYwav071.wav]
#
# File 92: Finished appending data for [Copy of randomPOLYwav074.wav]
#
# File 93: Finished appending data for [Copy of randomPOLYwav070.wav]
#
# File 94: Finished appending data for [Copy of randomPOLYwav079.wav]
#
# File 95: Finished appending data for [Copy of randomPOLYwav077.wav]
#
# File 96: Finished appending data for [Copy of randomPOLYwav078.wav]
#
# File 97: Finished appending data for [Copy of randomPOLYwav076.wav]
#
# File 98: Finished appending data for [Copy of randomPOLYwav072.wav]
#
# File 99: Finished appending data for [Copy of randomPOLYwav075.wav]
#
# File 100: Finished appending data for [Copy of randomPOLYwav069.wav]
#
# Data has been written to polyMaestroTrain.csv

# %%
fileDataList = []
fileNumber = 1
# csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
# csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
# csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
# csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
# csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvCombinedTrain):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvCombinedTrain, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'combinedTrain.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [Copy of playford1TRUNCATED.wav]
#
# File 2: Finished appending data for [Copy of morris29TRUNCATED.wav]
#
# File 3: Finished appending data for [Copy of morris30TRUNCATED.wav]
#
# File 4: Finished appending data for [Copy of playford7TRUNCATED.wav]
#
# File 5: Finished appending data for [Copy of playford6TRUNCATED.wav]
#
# File 6: Finished appending data for [Copy of morris31TRUNCATED.wav]
#
# File 7: Finished appending data for [Copy of playford8TRUNCATED.wav]
#
# File 8: Finished appending data for [Copy of playford4TRUNCATED.wav]
#
# File 9: Finished appending data for [Copy of playford3TRUNCATED.wav]
#
# File 10: Finished appending data for [Copy of playford2TRUNCATED.wav]
#
# File 11: Finished appending data for [Copy of playford13TRUNCATED.wav]
#
# File 12: Finished appending data for [Copy of playford10TRUNCATED.wav]
#
# File 13: Finished appending data for [Copy of playford14TRUNCATED.wav]
#
# File 14: Finished appending data for [Copy of playford9TRUNCATED.wav]
#
# File 15: Finished appending data for [Copy of reelsa-c1TRUNCATED.wav]
#
# File 16: Finished appending data for [Copy of playford11TRUNCATED.wav]
#
# File 17: Finished appending data for [Copy of reelsa-c3TRUNCATED.wav]
#
# File 18: Finished appending data for [Copy of reelsa-c2TRUNCATED.wav]
#
# File 19: Finished appending data for [Copy of playford15TRUNCATED.wav]
#
# File 20: Finished appending data for [Copy of playford12TRUNCATED.wav]
#
# File 21: Finished appending data for [Copy of reelsa-c5TRUNCATED.wav]
#
# File 22: Finished appending data for [Copy of reelsa-c7TRUNCATED.wav]
#
# File 23: Finished appending data for [Copy of reelsa-c4TRUNCATED.wav]
#
# File 24: Finished appending data for [Copy of reelsa-c8TRUNCATED.wav]
#
# File 25: Finished appending data for [Copy of reelsa-c6TRUNCATED.wav]
#
# File 26: Finished appending data for [Copy of MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--1TRUNCATED.wav]
#
# File 27: Finished appending data for [Copy of MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3TRUNCATED.wav]
#
# File 28: Finished appending data for [Copy of MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--3TRUNCATED.wav]
#
# File 29: Finished appending data for [Copy of MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--1TRUNCATED.wav]
#
# File 30: Finished appending data for [Copy of MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--2TRUNCATED.wav]
#
# File 31: Finished appending data for [Copy of MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--2TRUNCATED.wav]
#
# File 32: Finished appending data for [Copy of MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--1TRUNCATED.wav]
#
# File 33: Finished appending data for [Copy of MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--3TRUNCATED.wav]
#
# File 34: Finished appending data for [Copy of MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--2TRUNCATED.wav]
#
# File 35: Finished appending data for [Copy of MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--3TRUNCATED.wav]
#
# File 36: Finished appending data for [Copy of MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--4TRUNCATED.wav]
#
# File 37: Finished appending data for [Copy of MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--2TRUNCATED.wav]
#
# File 38: Finished appending data for [Copy of MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--1TRUNCATED.wav]
#
# File 39: Finished appending data for [Copy of MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--1TRUNCATED.wav]
#
# File 40: Finished appending data for [Copy of MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--3TRUNCATED.wav]
#
# File 41: Finished appending data for [Copy of MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--1TRUNCATED.wav]
#
# File 42: Finished appending data for [Copy of MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--4TRUNCATED.wav]
#
# File 43: Finished appending data for [Copy of MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--2TRUNCATED.wav]
#
# File 44: Finished appending data for [Copy of MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--4TRUNCATED.wav]
#
# File 45: Finished appending data for [Copy of MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2TRUNCATED.wav]
#
# File 46: Finished appending data for [Copy of MIDI-Unprocessed_070_PIANO070_MID--AUDIO-split_07-08-17_Piano-e_1-02_wav--3TRUNCATED.wav]
#
# File 47: Finished appending data for [Copy of MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--3TRUNCATED.wav]
#
# File 48: Finished appending data for [Copy of MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--2TRUNCATED.wav]
#
# File 49: Finished appending data for [Copy of MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1TRUNCATED.wav]
#
# File 50: Finished appending data for [Copy of MIDI-Unprocessed_070_PIANO070_MID--AUDIO-split_07-08-17_Piano-e_1-02_wav--2TRUNCATED.wav]
#
# File 51: Finished appending data for [Copy of randomMONOwav128.wav]
#
# File 52: Finished appending data for [Copy of randomMONOwav134.wav]
#
# File 53: Finished appending data for [Copy of randomMONOwav133.wav]
#
# File 54: Finished appending data for [Copy of randomMONOwav129.wav]
#
# File 55: Finished appending data for [Copy of randomMONOwav131.wav]
#
# File 56: Finished appending data for [Copy of randomMONOwav132.wav]
#
# File 57: Finished appending data for [Copy of randomMONOwav127.wav]
#
# File 58: Finished appending data for [Copy of randomMONOwav136.wav]
#
# File 59: Finished appending data for [Copy of randomMONOwav135.wav]
#
# File 60: Finished appending data for [Copy of randomMONOwav130.wav]
#
# File 61: Finished appending data for [Copy of randomMONOwav124.wav]
#
# File 62: Finished appending data for [Copy of randomMONOwav119.wav]
#
# File 63: Finished appending data for [Copy of randomMONOwav126.wav]
#
# File 64: Finished appending data for [Copy of randomMONOwav122.wav]
#
# File 65: Finished appending data for [Copy of randomMONOwav123.wav]
#
# File 66: Finished appending data for [Copy of randomMONOwav121.wav]
#
# File 67: Finished appending data for [Copy of randomMONOwav125.wav]
#
# File 68: Finished appending data for [Copy of randomMONOwav120.wav]
#
# File 69: Finished appending data for [Copy of randomMONOwav117.wav]
#
# File 70: Finished appending data for [Copy of randomMONOwav118.wav]
#
# File 71: Finished appending data for [Copy of randomMONOwav116.wav]
#
# File 72: Finished appending data for [Copy of randomMONOwav115.wav]
#
# File 73: Finished appending data for [Copy of randomMONOwav114.wav]
#
# File 74: Finished appending data for [Copy of randomMONOwav113.wav]
#
# File 75: Finished appending data for [Copy of randomMONOwav112.wav]
#
# File 76: Finished appending data for [Copy of randomPOLYwav125.wav]
#
# File 77: Finished appending data for [Copy of randomPOLYwav133.wav]
#
# File 78: Finished appending data for [Copy of randomPOLYwav130.wav]
#
# File 79: Finished appending data for [Copy of randomPOLYwav128.wav]
#
# File 80: Finished appending data for [Copy of randomPOLYwav132.wav]
#
# File 81: Finished appending data for [Copy of randomPOLYwav127.wav]
#
# File 82: Finished appending data for [Copy of randomPOLYwav131.wav]
#
# File 83: Finished appending data for [Copy of randomPOLYwav134.wav]
#
# File 84: Finished appending data for [Copy of randomPOLYwav129.wav]
#
# File 85: Finished appending data for [Copy of randomPOLYwav126.wav]
#
# File 86: Finished appending data for [Copy of randomPOLYwav123.wav]
#
# File 87: Finished appending data for [Copy of randomPOLYwav119.wav]
#
# File 88: Finished appending data for [Copy of randomPOLYwav124.wav]
#
# File 89: Finished appending data for [Copy of randomPOLYwav121.wav]
#
# File 90: Finished appending data for [Copy of randomPOLYwav117.wav]
#
# File 91: Finished appending data for [Copy of randomPOLYwav115.wav]
#
# File 92: Finished appending data for [Copy of randomPOLYwav118.wav]
#
# File 93: Finished appending data for [Copy of randomPOLYwav122.wav]
#
# File 94: Finished appending data for [Copy of randomPOLYwav120.wav]
#
# File 95: Finished appending data for [Copy of randomPOLYwav114.wav]
#
# File 96: Finished appending data for [Copy of randomPOLYwav111.wav]
#
# File 97: Finished appending data for [Copy of randomPOLYwav112.wav]
#
# File 98: Finished appending data for [Copy of randomPOLYwav110.wav]
#
# File 99: Finished appending data for [Copy of randomPOLYwav113.wav]
#
# File 100: Finished appending data for [Copy of randomPOLYwav109.wav]
#
# Data has been written to combinedTrain.csv

# %%
fileDataList = []
fileNumber = 1
# csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
# csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
# csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
# csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
# csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvMonophonicTest):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvMonophonicTest, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'monoNottinghamTest.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [reelsr-t62TRUNCATED.wav]
#
# File 2: Finished appending data for [reelsr-t49TRUNCATED.wav]
#
# File 3: Finished appending data for [reelsr-t70TRUNCATED.wav]
#
# File 4: Finished appending data for [reelsr-t64TRUNCATED.wav]
#
# File 5: Finished appending data for [reelsr-t66TRUNCATED.wav]
#
# File 6: Finished appending data for [reelsr-t67TRUNCATED.wav]
#
# File 7: Finished appending data for [reelsr-t48TRUNCATED.wav]
#
# File 8: Finished appending data for [reelsr-t57TRUNCATED.wav]
#
# File 9: Finished appending data for [reelsr-t47TRUNCATED.wav]
#
# File 10: Finished appending data for [reelsr-t68TRUNCATED.wav]
#
# File 11: Finished appending data for [reelsr-t69TRUNCATED.wav]
#
# File 12: Finished appending data for [reelsr-t59TRUNCATED.wav]
#
# File 13: Finished appending data for [reelsr-t52TRUNCATED.wav]
#
# File 14: Finished appending data for [reelsr-t58TRUNCATED.wav]
#
# File 15: Finished appending data for [reelsr-t50TRUNCATED.wav]
#
# File 16: Finished appending data for [reelsr-t61TRUNCATED.wav]
#
# File 17: Finished appending data for [reelsr-t65TRUNCATED.wav]
#
# File 18: Finished appending data for [reelsr-t63TRUNCATED.wav]
#
# File 19: Finished appending data for [reelsr-t60TRUNCATED.wav]
#
# File 20: Finished appending data for [reelsr-t55TRUNCATED.wav]
#
# File 21: Finished appending data for [reelsr-t53TRUNCATED.wav]
#
# File 22: Finished appending data for [reelsr-t56TRUNCATED.wav]
#
# File 23: Finished appending data for [reelsr-t51TRUNCATED.wav]
#
# File 24: Finished appending data for [reelsr-t46TRUNCATED.wav]
#
# File 25: Finished appending data for [reelsr-t54TRUNCATED.wav]
#
# File 26: Finished appending data for [Copy of randomMONOwav000.wav]
#
# File 27: Finished appending data for [Copy of randomMONOwav009.wav]
#
# File 28: Finished appending data for [Copy of randomMONOwav002.wav]
#
# File 29: Finished appending data for [Copy of randomMONOwav008.wav]
#
# File 30: Finished appending data for [Copy of randomMONOwav007.wav]
#
# File 31: Finished appending data for [Copy of randomMONOwav004.wav]
#
# File 32: Finished appending data for [Copy of randomMONOwav005.wav]
#
# File 33: Finished appending data for [Copy of randomMONOwav003.wav]
#
# File 34: Finished appending data for [Copy of randomMONOwav006.wav]
#
# File 35: Finished appending data for [Copy of randomMONOwav001.wav]
#
# File 36: Finished appending data for [Copy of randomMONOwav013.wav]
#
# File 37: Finished appending data for [Copy of randomMONOwav018.wav]
#
# File 38: Finished appending data for [Copy of randomMONOwav012.wav]
#
# File 39: Finished appending data for [Copy of randomMONOwav015.wav]
#
# File 40: Finished appending data for [Copy of randomMONOwav014.wav]
#
# File 41: Finished appending data for [Copy of randomMONOwav010.wav]
#
# File 42: Finished appending data for [Copy of randomMONOwav011.wav]
#
# File 43: Finished appending data for [Copy of randomMONOwav017.wav]
#
# File 44: Finished appending data for [Copy of randomMONOwav019.wav]
#
# File 45: Finished appending data for [Copy of randomMONOwav016.wav]
#
# File 46: Finished appending data for [Copy of randomMONOwav022.wav]
#
# File 47: Finished appending data for [Copy of randomMONOwav023.wav]
#
# File 48: Finished appending data for [Copy of randomMONOwav024.wav]
#
# File 49: Finished appending data for [Copy of randomMONOwav020.wav]
#
# File 50: Finished appending data for [Copy of randomMONOwav021.wav]
#
# Data has been written to monoNottinghamTest.csv

# %%
fileDataList = []
fileNumber = 1
# csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
# csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
# csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
# csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
# csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvPolyphonicTest):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvPolyphonicTest, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'polyMaestroTest.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--2TRUNCATED.wav]
#
# File 2: Finished appending data for [MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--4TRUNCATED.wav]
#
# File 3: Finished appending data for [MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--4TRUNCATED.wav]
#
# File 4: Finished appending data for [MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--3TRUNCATED.wav]
#
# File 5: Finished appending data for [MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--2TRUNCATED.wav]
#
# File 6: Finished appending data for [MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--4TRUNCATED.wav]
#
# File 7: Finished appending data for [MIDI-Unprocessed_048_PIANO048_MID--AUDIO-split_07-06-17_Piano-e_2-05_wav--1TRUNCATED.wav]
#
# File 8: Finished appending data for [MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--2TRUNCATED.wav]
#
# File 9: Finished appending data for [MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--1TRUNCATED.wav]
#
# File 10: Finished appending data for [MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--1TRUNCATED.wav]
#
# File 11: Finished appending data for [MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--4TRUNCATED.wav]
#
# File 12: Finished appending data for [MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--1TRUNCATED.wav]
#
# File 13: Finished appending data for [MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--3TRUNCATED.wav]
#
# File 14: Finished appending data for [MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--3TRUNCATED.wav]
#
# File 15: Finished appending data for [MIDI-Unprocessed_048_PIANO048_MID--AUDIO-split_07-06-17_Piano-e_2-05_wav--4TRUNCATED.wav]
#
# File 16: Finished appending data for [MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--2TRUNCATED.wav]
#
# File 17: Finished appending data for [MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--1TRUNCATED.wav]
#
# File 18: Finished appending data for [MIDI-Unprocessed_048_PIANO048_MID--AUDIO-split_07-06-17_Piano-e_2-05_wav--2TRUNCATED.wav]
#
# File 19: Finished appending data for [MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--1TRUNCATED.wav]
#
# File 20: Finished appending data for [MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--1TRUNCATED.wav]
#
# File 21: Finished appending data for [MIDI-Unprocessed_046_PIANO046_MID--AUDIO-split_07-06-17_Piano-e_2-02_wav--2TRUNCATED.wav]
#
# File 22: Finished appending data for [MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--3TRUNCATED.wav]
#
# File 23: Finished appending data for [MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--2TRUNCATED.wav]
#
# File 24: Finished appending data for [MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--3TRUNCATED.wav]
#
# File 25: Finished appending data for [MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--4TRUNCATED.wav]
#
# File 26: Finished appending data for [Copy of randomPOLYwav001.wav]
#
# File 27: Finished appending data for [Copy of randomPOLYwav009.wav]
#
# File 28: Finished appending data for [Copy of randomPOLYwav006.wav]
#
# File 29: Finished appending data for [Copy of randomPOLYwav003.wav]
#
# File 30: Finished appending data for [Copy of randomPOLYwav005.wav]
#
# File 31: Finished appending data for [Copy of randomPOLYwav004.wav]
#
# File 32: Finished appending data for [Copy of randomPOLYwav007.wav]
#
# File 33: Finished appending data for [Copy of randomPOLYwav008.wav]
#
# File 34: Finished appending data for [Copy of randomPOLYwav002.wav]
#
# File 35: Finished appending data for [Copy of randomPOLYwav000.wav]
#
# File 36: Finished appending data for [Copy of randomPOLYwav013.wav]
#
# File 37: Finished appending data for [Copy of randomPOLYwav016.wav]
#
# File 38: Finished appending data for [Copy of randomPOLYwav015.wav]
#
# File 39: Finished appending data for [Copy of randomPOLYwav010.wav]
#
# File 40: Finished appending data for [Copy of randomPOLYwav018.wav]
#
# File 41: Finished appending data for [Copy of randomPOLYwav011.wav]
#
# File 42: Finished appending data for [Copy of randomPOLYwav017.wav]
#
# File 43: Finished appending data for [Copy of randomPOLYwav012.wav]
#
# File 44: Finished appending data for [Copy of randomPOLYwav014.wav]
#
# File 45: Finished appending data for [Copy of randomPOLYwav019.wav]
#
# File 46: Finished appending data for [Copy of randomPOLYwav021.wav]
#
# File 47: Finished appending data for [Copy of randomPOLYwav024.wav]
#
# File 48: Finished appending data for [Copy of randomPOLYwav022.wav]
#
# File 49: Finished appending data for [Copy of randomPOLYwav023.wav]
#
# File 50: Finished appending data for [Copy of randomPOLYwav020.wav]
#
# Data has been written to polyMaestroTest.csv

# %%
fileDataList = []
fileNumber = 1
# csvMonophonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTrain[100]"
# csvPolyphonicTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTrain[100]"
# csvCombinedTrain = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTrain[100]"
# csvMonophonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/NottinghamMonoTest[50]"
# csvPolyphonicTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/MaestroPolyTest[50]"
csvCombinedTest = "/content/drive/Shareddrives/neotyagi-dataset/CSV Creation/CombinedTest[52]"

# Criteria 1 Constants and Definition ==========================================

noteInTuneTolerance = 7
pieceInTuneThreshold = 85
noteFrequencies = [
    65.41, 69.30, 73.42, 77.78, 82.41, 87.31, 92.50, 98.00, 103.83, 110.00, 116.54,
    123.47, 130.81, 138.59, 146.83, 155.56, 164.81, 174.61, 185.00, 196.00, 207.65,
    220.00, 233.08, 246.94, 261.63, 277.18, 293.66, 311.13, 329.63, 349.23, 369.99,
    392.00, 415.30, 440.00, 466.16, 493.88, 523.25, 554.37, 587.33, 622.25, 659.26,
    698.46, 739.99, 783.99, 830.61, 880.00, 932.33, 987.77, 1046.50, 1108.73, 1174.66,
    1244.51, 1318.51, 1396.91, 1479.98, 1567.98, 1661.22, 1760.00, 1864.66, 1975.53
]

def findClosestNoteFrequency(frequency):
    return min(noteFrequencies, key = lambda x: abs(x - frequency))

# Criteria 2 Definition ========================================================

def hasRandomNotes(audioFile, maxStabilityThreshold = 0.07, maxNoteRepetitions = 5, maxNoteDistributionStability = 14):
    audioData, sampleRate = librosa.load(audioFile)

    cqt = librosa.cqt(y = audioData, sr = sampleRate)                            # Calculate the constant-Q chromagram [a representation of an audio signal that captures the energy distribution of different pitches over time].
    chromagram = librosa.amplitude_to_db(np.abs(cqt), ref=np.max)               # Convert to decibels for easier analysis.

    # Calculating the note distribution stability
    noteDistributionStability = np.std(chromagram, axis=0).mean()

    onsetStrength = librosa.onset.onset_strength(y = audioData, sr = sampleRate) # Onset Strength: The magnitude of sudden changes in the audio signal [beginning of a note].
    tempo, _ = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate)
    _, beatTimes = librosa.beat.beat_track(onset_envelope = onsetStrength, sr = sampleRate, units = 'time') # Estimating the tempo and the beat times.

    meanTempoInterval = np.mean(np.diff(beatTimes))
    meanTempoIntervalStandardDeviation = np.std(np.diff(beatTimes))
    rhythmicStability = meanTempoIntervalStandardDeviation / meanTempoInterval

    noteOnsets = librosa.onset.onset_detect(y = audioData, sr = sampleRate)     # Detects the beginning of notes and calculating the maximum note repetitions in the audio.
    noteIntervals = np.diff(noteOnsets)
    maxNoteReps = np.max(np.bincount(noteIntervals))

    return rhythmicStability, noteDistributionStability, maxNoteReps

# Criteria 3 Definition ========================================================

def analyzeMelodicStructure(audioFile):
    audioData, samplingRate = librosa.load(audioFile)

    pitches, magnitudes = librosa.core.piptrack(y = audioData, sr = samplingRate) # Compute the pitch (fundamental frequency - lowest frequency) over time

    pitchContour = pitches[np.argmax(magnitudes, axis=0)]
    pitchContour = pitchContour.ravel()  # Flatten to a 1D Array.

    melodicIntervals = np.diff(pitchContour)                                    # Melodic intervals are the differences between consecutive pitch values.
    melodicPeaks, _ = find_peaks(pitchContour)
    melodicComplexity = np.std(melodicIntervals)                                # Measures the standard deviation of the intervals between consecutive pitches in the melodic contour.


    melodicStabilityRange = np.max(pitchContour) - np.min(pitchContour)         # Measures the span between the highest and lowest pitches in the melodic contour.
    noteDurations = np.diff(melodicPeaks) / samplingRate
    dynamicVariation = np.std(audioData)

    return melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation

# Data to CSV Implementation ===================================================

for filename in os.listdir(csvCombinedTest):
  totalNotes = 0

  if "random" in filename:
    isSignificant = False
  else:
      isSignificant = True

  if filename.endswith(".wav"):
    filepath = os.path.join(csvCombinedTest, filename)
    audioData, sampleRate = librosa.load(filepath, sr = None)
    inTuneCount = 0

    frequencyEstimatesPYIN = librosa.pyin(audioData, fmin = librosa.note_to_hz('C2'), fmax = librosa.note_to_hz('C7'), fill_na = -1)
    frequencies = frequencyEstimatesPYIN[0]
    magnitudes = frequencyEstimatesPYIN[1]


    for i in range(0, len(frequencies), 5):
      frequency = frequencies[i]
      if frequency > 0:
        closestNoteFrequency = findClosestNoteFrequency(frequency)
        if abs(frequency - closestNoteFrequency) <= noteInTuneTolerance:
            inTuneCount += 1
        totalNotes+=1

    percentageInTune = (inTuneCount / totalNotes) * 100

# End of Criteria 1 ############################################################

    rhythmStability, noteDistributionStability, maxNoteRepetitions = hasRandomNotes(filepath)

# End of Criteria 2 ############################################################

    melodicPeaks, melodicComplexity, melodicStabilityRange, noteDurations, dynamicVariation = analyzeMelodicStructure(filepath)

# End of Criteria 3 ############################################################

    fileData = {
      'Filenumber': fileNumber,
      'Filename': filename,
      '% In-Tune Notes': percentageInTune,
      'Rhythmic Stability': rhythmStability,
      'Note Distribution Stability': noteDistributionStability,
      'Melodic Stability Range': melodicStabilityRange,
      'Dynamic Variation': dynamicVariation,
      'Significant': isSignificant
    }

    fileDataList.append(fileData)
    print(f"File {fileNumber}: Finished appending data for [{filename}]\n")
    fileNumber+=1

csv_columns = [
  'Filenumber', 'Filename', '% In-Tune Notes', 'Rhythmic Stability',
  'Note Distribution Stability',
  'Melodic Stability Range', 'Dynamic Variation', 'Significant'
]

csvFileName = 'combinedTest.csv'

with open(csvFileName, 'w', newline = '') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=csv_columns)

    # Write the header
    writer.writeheader()

    # Write the data for each file
    for data in fileDataList:
        writer.writerow(data)

print(f"Data has been written to {csvFileName}")
# Out:
# File 1: Finished appending data for [Copy of randomMONOwav140.wav]
#
# File 2: Finished appending data for [Copy of randomMONOwav142.wav]
#
# File 3: Finished appending data for [Copy of randomMONOwav145.wav]
#
# File 4: Finished appending data for [Copy of randomMONOwav141.wav]
#
# File 5: Finished appending data for [Copy of randomMONOwav144.wav]
#
# File 6: Finished appending data for [Copy of randomMONOwav148.wav]
#
# File 7: Finished appending data for [Copy of randomMONOwav146.wav]
#
# File 8: Finished appending data for [Copy of randomMONOwav147.wav]
#
# File 9: Finished appending data for [Copy of randomMONOwav143.wav]
#
# File 10: Finished appending data for [Copy of randomMONOwav149.wav]
#
# File 11: Finished appending data for [Copy of randomMONOwav139.wav]
#
# File 12: Finished appending data for [Copy of randomMONOwav137.wav]
#
# File 13: Finished appending data for [Copy of randomMONOwav138.wav]
#
# File 14: Finished appending data for [Copy of randomPOLYwav149.wav]
#
# File 15: Finished appending data for [Copy of randomPOLYwav140.wav]
#
# File 16: Finished appending data for [Copy of randomPOLYwav147.wav]
#
# File 17: Finished appending data for [Copy of randomPOLYwav143.wav]
#
# File 18: Finished appending data for [Copy of randomPOLYwav148.wav]
#
# File 19: Finished appending data for [Copy of randomPOLYwav139.wav]
#
# File 20: Finished appending data for [Copy of randomPOLYwav141.wav]
#
# File 21: Finished appending data for [Copy of randomPOLYwav144.wav]
#
# File 22: Finished appending data for [Copy of randomPOLYwav145.wav]
#
# File 23: Finished appending data for [Copy of randomPOLYwav146.wav]
#
# File 24: Finished appending data for [Copy of randomPOLYwav136.wav]
#
# File 25: Finished appending data for [Copy of randomPOLYwav137.wav]
#
# File 26: Finished appending data for [Copy of randomPOLYwav138.wav]
#
# File 27: Finished appending data for [Copy of MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--3TRUNCATED.wav]
#
# File 28: Finished appending data for [Copy of MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--4TRUNCATED.wav]
#
# File 29: Finished appending data for [Copy of MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--1TRUNCATED.wav]
#
# File 30: Finished appending data for [Copy of MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--5TRUNCATED.wav]
#
# File 31: Finished appending data for [Copy of MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--2TRUNCATED.wav]
#
# File 32: Finished appending data for [Copy of MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--3TRUNCATED.wav]
#
# File 33: Finished appending data for [Copy of MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--3TRUNCATED.wav]
#
# File 34: Finished appending data for [Copy of MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--1TRUNCATED.wav]
#
# File 35: Finished appending data for [Copy of MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--4TRUNCATED.wav]
#
# File 36: Finished appending data for [Copy of MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--2TRUNCATED.wav]
#
# File 37: Finished appending data for [Copy of MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--3TRUNCATED.wav]
#
# File 38: Finished appending data for [Copy of MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--2TRUNCATED.wav]
#
# File 39: Finished appending data for [Copy of MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--1TRUNCATED.wav]
#
# File 40: Finished appending data for [Copy of morris10TRUNCATED.wav]
#
# File 41: Finished appending data for [Copy of morris5TRUNCATED.wav]
#
# File 42: Finished appending data for [Copy of morris9TRUNCATED.wav]
#
# File 43: Finished appending data for [Copy of morris3TRUNCATED.wav]
#
# File 44: Finished appending data for [Copy of morris7TRUNCATED.wav]
#
# File 45: Finished appending data for [Copy of morris8TRUNCATED.wav]
#
# File 46: Finished appending data for [Copy of morris6TRUNCATED.wav]
#
# File 47: Finished appending data for [Copy of morris4TRUNCATED.wav]
#
# File 48: Finished appending data for [Copy of morris2TRUNCATED.wav]
#
# File 49: Finished appending data for [Copy of morris1TRUNCATED.wav]
#
# File 50: Finished appending data for [Copy of jigs340TRUNCATED.wav]
#
# File 51: Finished appending data for [Copy of jigs339TRUNCATED.wav]
#
# File 52: Finished appending data for [Copy of jigs338TRUNCATED.wav]
#
# Data has been written to combinedTest.csv
